# %%
# Libraries Used 
import pandas as pd
import numpy as np 
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %%
tickers = ['AMZN', 'AAPL', 'PFE', 'AZN', 'BABA', 'AGNC', 'BRK-B', 'BA', 'LUV', 'DAL', 'EADSY']
# weights = np.array([.3525, .1822, .0424, .0622, .2776, .0180, .0650])
# indices = ['^DJI', '^IXIC', '^GSPC'] 
my_data = pd.DataFrame()
for t in tickers:
    my_data[t] = wb.DataReader(t, data_source='yahoo', start='2000-1-1')['Adj Close']

# %%
my_data = my_data.dropna()
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1478 entries, 2014-09-19 to 2020-08-03
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AMZN    1478 non-null   float64
#  1   AAPL    1478 non-null   float64
#  2   PFE     1478 non-null   float64
#  3   AZN     1478 non-null   float64
#  4   BABA    1478 non-null   float64
#  5   AGNC    1478 non-null   float64
#  6   BRK-B   1478 non-null   float64
#  7   BA      1478 non-null   float64
#  8   LUV     1478 non-null   float64
#  9   DAL     1478 non-null   float64
#  10  EADSY   1478 non-null   float64
# dtypes: float64(11)
# memory usage: 138.6 KB

# %%
sec_returns = np.log(my_data/my_data.shift(1))
sec_returns


sec_returns = sec_returns.dropna()
sec_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1477 entries, 2014-09-22 to 2020-08-03
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AMZN    1477 non-null   float64
#  1   AAPL    1477 non-null   float64
#  2   PFE     1477 non-null   float64
#  3   AZN     1477 non-null   float64
#  4   BABA    1477 non-null   float64
#  5   AGNC    1477 non-null   float64
#  6   BRK-B   1477 non-null   float64
#  7   BA      1477 non-null   float64
#  8   LUV     1477 non-null   float64
#  9   DAL     1477 non-null   float64
#  10  EADSY   1477 non-null   float64
# dtypes: float64(11)
# memory usage: 138.5 KB

# %% [markdown]
# ## Data Analysis

# %%
sec_returns
# Out:
#                 AMZN      AAPL       PFE       AZN      BABA          AGNC  \
# Date
# 2014-09-22 -0.020799  0.000990 -0.007263 -0.000669 -0.043537 -9.393660e-03
# 2014-09-23 -0.002685  0.015513 -0.004317 -0.048569 -0.030726 -3.602477e-03
# 2014-09-24  0.014053 -0.008709  0.008615  0.007424  0.038263 -3.614975e-03
# 2014-09-25 -0.019320 -0.038879 -0.010947 -0.009394 -0.018386  4.523014e-04
# 2014-09-26  0.003968  0.029002 -0.008710  0.013571  0.017171  2.637242e-07
# ...              ...       ...       ...       ...       ...           ...
# 2020-07-28 -0.018126 -0.016564  0.038667 -0.004606 -0.007241 -1.026407e-02
# 2020-07-29  0.011005  0.018987  0.006132  0.005666  0.013560  1.463094e-02
# 2020-07-30  0.006031  0.012028 -0.003607  0.021829  0.001148 -2.200271e-03
# 2020-07-31  0.036294  0.099564 -0.006734 -0.037129 -0.006829 -1.469472e-03
# 2020-08-03 -0.014299  0.025895 -0.002993  0.017593  0.024010  8.784821e-03
#
#                BRK-B        BA       LUV       DAL     EADSY
# Date
# 2014-09-22 -0.009292 -0.005737 -0.011934 -0.018019 -0.003165
# 2014-09-23 -0.003453 -0.009610 -0.026407 -0.006609 -0.036156
# 2014-09-24  0.008395  0.009377  0.031664 -0.001062 -0.000658
# 2014-09-25 -0.020648 -0.011262 -0.020304 -0.026912  0.009820
# 2014-09-26  0.011531  0.012117  0.007994 -0.003826  0.021271
# ...              ...       ...       ...       ...       ...
# 2020-07-28  0.010252  0.003694  0.023818  0.017108  0.015226
# 2020-07-29  0.011728 -0.028679 -0.015606 -0.008517 -0.013037
# 2020-07-30 -0.010801 -0.024760 -0.026456 -0.030796  0.027502
# 2020-07-31  0.007588 -0.024693 -0.002264  0.001202 -0.036289
# 2020-08-03  0.020525  0.026944  0.025411  0.011547  0.023441
#
# [1477 rows x 11 columns]

# %%
for t in tickers:

    
    print("")
    print("#",t)
    print("DAILY")
    print("Daily Return:", round(sec_returns[t].mean()*100, 4), "%")
    print("Daily Risk:", round(sec_returns[t].std()*100, 4), "%")

    print("")

    print("ANNUAL")
    mean_return = round((sec_returns[t].mean()*250)*100, 4)
    std_return = round((sec_returns[t].std()*250**.5)*100, 4)
    print("Annual Return:", mean_return, "%")
    print("Annual Risk:", std_return, "%")
# Out:
# # AMZN
# DAILY
# Daily Return: 0.1518 %
# Daily Risk: 1.914 %
#
# ANNUAL
# Annual Return: 37.9557 %
# Annual Risk: 30.263 %
#
# # AAPL
# DAILY
# Daily Return: 0.1054 %
# Daily Risk: 1.7979 %
#
# ANNUAL
# Annual Return: 26.3612 %
# Annual Risk: 28.4269 %
#
# # PFE
# DAILY
# Daily Return: 0.0306 %
# Daily Risk: 1.3426 %
#
# ANNUAL
# Annual Return: 7.6378 %
# Annual Risk: 21.2277 %
#
# # AZN
# DAILY
# Daily Return: 0.0476 %
# Daily Risk: 1.5956 %
#
# ANNUAL
# Annual Return: 11.8975 %
# Annual Risk: 25.228 %
#
# # BABA
# DAILY
# Daily Return: 0.0682 %
# Daily Risk: 2.0607 %
#
# ANNUAL
# Annual Return: 17.0518 %
# Annual Risk: 32.5822 %
#
# # AGNC
# DAILY
# Daily Return: 0.0148 %
# Daily Risk: 1.5209 %
#
# ANNUAL
# Annual Return: 3.7012 %
# Annual Risk: 24.0473 %
#
# # BRK-B
# DAILY
# Daily Return: 0.0238 %
# Daily Risk: 1.3032 %
#
# ANNUAL
# Annual Return: 5.956 %
# Annual Risk: 20.6059 %
#
# # BA
# DAILY
# Daily Return: 0.0254 %
# Daily Risk: 2.601 %
#
# ANNUAL
# Annual Return: 6.3387 %
# Annual Risk: 41.1255 %
#
# # LUV
# DAILY
# Daily Return: -0.0023 %
# Daily Risk: 2.2533 %
#
# ANNUAL
# Annual Return: -0.5631 %
# Annual Risk: 35.6281 %
#
# # DAL
# DAILY
# Daily Return: -0.0215 %
# Daily Risk: 2.5758 %
#
# ANNUAL
# Annual Return: -5.3774 %
# Annual Risk: 40.7273 %
#
# # EADSY
# DAILY
# Daily Return: 0.0193 %
# Daily Risk: 2.422 %
#
# ANNUAL
# Annual Return: 4.8331 %
# Annual Risk: 38.2945 %

# %%
sec_returns.idxmin()
# Out:
# AMZN    2014-10-24
# AAPL    2020-03-16
# PFE     2020-03-16
# AZN     2017-07-27
# BABA    2015-01-29
# AGNC    2020-03-12
# BRK-B   2020-03-12
# BA      2020-03-16
# LUV     2020-03-12
# DAL     2020-03-18
# EADSY   2020-03-18
# dtype: datetime64[ns]

# %%
sec_returns.idxmax()
# Out:
# AMZN    2015-04-24
# AAPL    2020-03-13
# PFE     2020-03-13
# AZN     2019-02-14
# BABA    2017-06-08
# AGNC    2020-03-25
# BRK-B   2020-03-13
# BA      2020-03-25
# LUV     2020-03-13
# DAL     2020-03-24
# EADSY   2020-03-26
# dtype: datetime64[ns]

# %%
# Covariance 
# Determines if there is a relationship between two stocks, whether they move together:
# positively, negatively, or neutral 
return_cov = sec_returns.cov()
return_cov
# Out:
#            AMZN      AAPL       PFE       AZN      BABA      AGNC     BRK-B  \
# AMZN   0.000366  0.000184  0.000081  0.000086  0.000189  0.000052  0.000098
# AAPL   0.000184  0.000323  0.000101  0.000105  0.000173  0.000079  0.000138
# PFE    0.000081  0.000101  0.000180  0.000090  0.000076  0.000053  0.000099
# AZN    0.000086  0.000105  0.000090  0.000255  0.000089  0.000050  0.000076
# BABA   0.000189  0.000173  0.000076  0.000089  0.000425  0.000052  0.000104
# AGNC   0.000052  0.000079  0.000053  0.000050  0.000052  0.000231  0.000080
# BRK-B  0.000098  0.000138  0.000099  0.000076  0.000104  0.000080  0.000170
# BA     0.000144  0.000212  0.000129  0.000109  0.000174  0.000210  0.000204
# LUV    0.000106  0.000153  0.000102  0.000089  0.000136  0.000135  0.000157
# DAL    0.000112  0.000179  0.000115  0.000100  0.000164  0.000191  0.000190
# EADSY  0.000126  0.000171  0.000108  0.000123  0.000170  0.000179  0.000171
#
#              BA       LUV       DAL     EADSY
# AMZN   0.000144  0.000106  0.000112  0.000126
# AAPL   0.000212  0.000153  0.000179  0.000171
# PFE    0.000129  0.000102  0.000115  0.000108
# AZN    0.000109  0.000089  0.000100  0.000123
# BABA   0.000174  0.000136  0.000164  0.000170
# AGNC   0.000210  0.000135  0.000191  0.000179
# BRK-B  0.000204  0.000157  0.000190  0.000171
# BA     0.000677  0.000326  0.000420  0.000378
# LUV    0.000326  0.000508  0.000448  0.000256
# DAL    0.000420  0.000448  0.000663  0.000344
# EADSY  0.000378  0.000256  0.000344  0.000587

# %%
# Correlations
# Determines how close the relationship are between two stocks
return_corr = sec_returns.corr()
return_corr
# Out:
#            AMZN      AAPL       PFE       AZN      BABA      AGNC     BRK-B  \
# AMZN   1.000000  0.533974  0.314257  0.281424  0.479253  0.177083  0.393099
# AAPL   0.533974  1.000000  0.419526  0.364594  0.466456  0.289667  0.587003
# PFE    0.314257  0.419526  1.000000  0.418320  0.273807  0.258536  0.563301
# AZN    0.281424  0.364594  0.418320  1.000000  0.271340  0.207262  0.365994
# BABA   0.479253  0.466456  0.273807  0.271340  1.000000  0.167165  0.385450
# AGNC   0.177083  0.289667  0.258536  0.207262  0.167165  1.000000  0.403453
# BRK-B  0.393099  0.587003  0.563301  0.365994  0.385450  0.403453  1.000000
# BA     0.289482  0.453976  0.368402  0.263460  0.323970  0.531964  0.601524
# LUV    0.245005  0.377805  0.336740  0.248787  0.293546  0.393710  0.533250
# DAL    0.227492  0.386739  0.332400  0.243174  0.308797  0.487714  0.564674
# EADSY  0.272411  0.391627  0.331193  0.318354  0.341616  0.485453  0.541734
#
#              BA       LUV       DAL     EADSY
# AMZN   0.289482  0.245005  0.227492  0.272411
# AAPL   0.453976  0.377805  0.386739  0.391627
# PFE    0.368402  0.336740  0.332400  0.331193
# AZN    0.263460  0.248787  0.243174  0.318354
# BABA   0.323970  0.293546  0.308797  0.341616
# AGNC   0.531964  0.393710  0.487714  0.485453
# BRK-B  0.601524  0.533250  0.564674  0.541734
# BA     1.000000  0.556963  0.626413  0.599647
# LUV    0.556963  1.000000  0.771440  0.468559
# DAL    0.626413  0.771440  1.000000  0.551636
# EADSY  0.599647  0.468559  0.551636  1.000000

# %% [markdown]
# ## Data Visualization

# %%
(my_data/my_data.iloc[0]*100).plot(figsize=(20,15))

# %%
sns.set_style('whitegrid')
sns.pairplot(sec_returns[1:], kind="reg")

# %%
plt.subplots(figsize=(15, 15))
sns.heatmap(return_corr, annot=True, square=True, cmap='coolwarm')
#plt.show()
